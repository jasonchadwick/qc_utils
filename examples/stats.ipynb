# %%
import sys
sys.path.append('../')

import numpy as np
import matplotlib.pyplot as plt

import qc_utils.stats as stats

# %%
stats.fit_binomial(num_shots=10**6, num_hits=10, max_likelihood_factor=1000)
# Out:
# (2.33e-06, 2.675e-05)

# %%
ps = np.full(2**10, 0.01)
for i in np.random.randint(0, 2**10, 10):
    ps[i] = np.random.random()

# %%
stats.get_most_probable_bitstrings(ps, 100, probability_threshold=1e-6)
# Out:
# (array([[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]]),
#  array([4.41957020e-06, 1.83415800e-06, 1.75690972e-06, 1.64843489e-06,
#         1.39565750e-06, 1.13016749e-06, 1.09883392e-06]))

# %%
vals = np.linspace(0, 10, 100) + np.random.normal(0, 1, 100)

# %%
plt.plot(range(100), vals, 'o')
avg, xs = stats.moving_average(vals, 20, return_x = True)
plt.plot(xs, avg)
